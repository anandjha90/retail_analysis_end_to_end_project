# %%
pip install snowflake-connector-python
# Out:
# ...
#      ---------------------------------------- 10.7/10.7 MB 4.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.7/1.7 MB 3.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 105.0/105.0 kB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 194.6/194.6 kB 2.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install snowflake-sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import snowflake.connector

# %%
account = 'obtaxoh-pw38465'
user = 'SQLTECH'
password = 'Revolt1857'
database = 'BANKING'
schema = 'PUBLIC'
warehouse = 'COMPUTE_WH'

# %%
conn = snowflake.connector.connect(
    user=user,
    password=password,
    account=account,
    database=database,
    schema=schema,
    warehouse=warehouse
)

# %%
cur=conn.cursor()

# %%
cur.execute("SELECT * FROM bank_details")

# %%
import pandas as pd

# %%
pip install "snowflake-connector-python[pandas]"
# Out:
# ...
#      ---------------------------------------- 20.3/20.3 MB 2.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = cur.fetch_pandas_all()

# %%
df
# Out:
#     AGE           JOB   MARITAL  EDUCATION `DEFAULT`  BALANCE HOUSING LOAN  \
# 0    44    technician    single  secondary        no       29     yes   no
# 1    33  entrepreneur   married  secondary        no        2     yes  yes
# 2    47   blue-collar   married    unknown        no     1506     yes   no
# 3    33       unknown    single    unknown        no        1      no   no
# 4    35    management   married   tertiary        no      231     yes   no
# ..  ...           ...       ...        ...       ...      ...     ...  ...
# 87   46    management  divorced  secondary        no       16     yes  yes
# 88   57       retired   married  secondary        no      486     yes   no
# 89   42    management    single  secondary        no       50      no   no
# 90   30    technician   married  secondary        no      152     yes  yes
# 91   60        admin.   married  secondary        no      290     yes   no
#
# ...

# %%
cur.close()
conn.close()

# %%
import snowflake.connector
from sqlalchemy import create_engine
import pandas as pd

# %%
account = 'obtaxoh-pw38465'
user = 'SQLTECH'
password = 'Revolt1857'
database = 'BANKING'
schema = 'PUBLIC'
warehouse = 'COMPUTE_WH'

# %%
df1 = pd.DataFrame({
    "col1": [1, 2, 3],
    "col2": ["a", "b", "c"],
    "col3": [True, False, True]
})

# %%
df1
# Out:
#    col1 col2   col3
# 0     1    a   True
# 1     2    b  False
# 2     3    c   True

# %%
from sqlalchemy import create_engine

# %%
connection_string = f"snowflake://{user}:{password}@{account}/{database}/{schema}?warehouse={warehouse}"

# %%
engine = create_engine(connection_string)

# %%
df1.to_sql(name="feeding_back_data",con = engine,if_exists="replace",index=False)
# Out:
# 3

# %%
engine.dispose()

# %%
df
# Out:
#     AGE           JOB   MARITAL  EDUCATION `DEFAULT`  BALANCE HOUSING LOAN  \
# 0    44    technician    single  secondary        no       29     yes   no
# 1    33  entrepreneur   married  secondary        no        2     yes  yes
# 2    47   blue-collar   married    unknown        no     1506     yes   no
# 3    33       unknown    single    unknown        no        1      no   no
# 4    35    management   married   tertiary        no      231     yes   no
# ..  ...           ...       ...        ...       ...      ...     ...  ...
# 87   46    management  divorced  secondary        no       16     yes  yes
# 88   57       retired   married  secondary        no      486     yes   no
# 89   42    management    single  secondary        no       50      no   no
# 90   30    technician   married  secondary        no      152     yes  yes
# 91   60        admin.   married  secondary        no      290     yes   no
#
# ...

# %%
df.drop("`DEFAULT`",axis=1,inplace=True)

# %%
df
# Out:
#     AGE           JOB   MARITAL  EDUCATION  BALANCE HOUSING LOAN  CONTACT  \
# 0    44    technician    single  secondary       29     yes   no  unknown
# 1    33  entrepreneur   married  secondary        2     yes  yes  unknown
# 2    47   blue-collar   married    unknown     1506     yes   no  unknown
# 3    33       unknown    single    unknown        1      no   no  unknown
# 4    35    management   married   tertiary      231     yes   no  unknown
# ..  ...           ...       ...        ...      ...     ...  ...      ...
# 87   46    management  divorced  secondary       16     yes  yes  unknown
# 88   57       retired   married  secondary      486     yes   no  unknown
# 89   42    management    single  secondary       50      no   no  unknown
# 90   30    technician   married  secondary      152     yes  yes  unknown
# 91   60        admin.   married  secondary      290     yes   no  unknown
#
#     `DAY` `MONTH`  DURATION  CAMPAIGN  PDAYS  PREVIOUS POUTCOME   Y
# ...

# %%
df.to_sql(name="bank2",con=engine,if_exists="replace",index=False)
# Out:
# 92

# %%
engine.dispose()
